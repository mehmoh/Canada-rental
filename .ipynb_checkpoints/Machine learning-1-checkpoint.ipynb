# %%
import numpy as np
from sklearn import neighbors 
from sklearn.metrics import mean_squared_error
#from math import sqrt
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm
from sklearn import neighbors

# %%
df = pd.read_csv('cleaned.csv').drop(['Unnamed: 0'],axis=1)
df=df.dropna()
df
# Out:
#       price             Address  bedroom  bathroom  size_sqf      types  \
# 0      1425              Poplar        1         1       533  Apt/Condo
# 1      2245              Poplar        2         2       910  Apt/Condo
# 2      1350     Abbotsford West        1         1       538  Apt/Condo
# 3      1725              Poplar        1         1       689  Apt/Condo
# 4      1625  Central Abbotsford        2         1       846  Apt/Condo
# ...     ...                 ...      ...       ...       ...        ...
# 3363   1535          Av. Lennox        1         1       700      House
# 3364   6999   Rue Sherbrooke O.        2         2      1175      House
# 3365   1437        Av. Somerled        2         1       770      House
# 3366   3500       Tsse St-Denis        3         2      1800      House
# 3367   2495         Rue Muir #A        2         2      1192      House
#
#             city province   Latitude   Longitude
# 0     Abbotsford       BC  49.075942 -122.247779
# 1     Abbotsford       BC  49.075942 -122.247779
# 2     Abbotsford       BC  49.039034 -122.430243
# 3     Abbotsford       BC  49.075942 -122.247779
# 4     Abbotsford       BC  49.050438 -122.304470
# ...          ...      ...        ...         ...
# 3363    Montreal   Quebec  45.512978  -73.624023
# 3364    Montreal   Quebec  45.481598  -73.600424
# 3365    Montreal   Quebec  45.467881  -73.638234
# 3366    Montreal   Quebec  45.516377  -73.566669
# 3367    Montreal   Quebec  45.525291  -73.677420
#
# [3368 rows x 10 columns]

# %% [markdown]
# # Model 1(ols) with province and without city

# %%
#creating training and testing datasets
df1=df.drop(columns=['Address','city','Latitude','Longitude'])# I only control for province. because adress and city are nested into province
df1['bedroom']=df1['bedroom'].astype("category") # I convert bedrooms to categorical because 
# it makes sense to think that there is not a linear relationship between 1 to 2 and 2 to 3 bedrooms places/
df1['size_sqf_q2']=df1['size_sqf']*df1['size_sqf'] 
#I added bigger places additional square feet has smaller impact on price than small places. 
df_dummies = pd.get_dummies(data=df1, drop_first=True)
training_data = df_dummies.sample(frac=0.8, random_state=25)
testing_data = df_dummies.drop(training_data.index)
training_data=training_data.reset_index(drop=True)
testing_data=testing_data.reset_index(drop=True)

# %%
X=training_data.drop(columns=['price'])
X= sm.add_constant(X) #adding constant to the model

Y=training_data['price']

# %%
model1 = sm.OLS(Y,X).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     173.7
# Date:                Thu, 10 Feb 2022   Prob (F-statistic):               0.00
# Time:                        13:37:33   Log-Likelihood:                -21907.
# No. Observations:                2694   AIC:                         4.385e+04
# Df Residuals:                    2674   BIC:                         4.397e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               297.1901     98.975      3.003      0.003     103.115     491.265
# bathroom            481.4315     34.234     14.063      0.000     414.304     548.558
# size_sqf             -0.2738      0.189     -1.449      0.147      -0.644       0.097
# size_sqf_q2           0.0005    6.3e-05      7.603      0.000       0.000       0.001
# bedroom_1           267.6216     72.351      3.699      0.000     125.752     409.491
# bedroom_2           415.6225     85.240      4.876      0.000     248.480     582.765
# bedroom_3           420.4235    108.687      3.868      0.000     207.305     633.542
# bedroom_4           -19.3965    144.046     -0.135      0.893    -301.850     263.057
# bedroom_5         -1955.5315    335.629     -5.826      0.000   -2613.651   -1297.412
# bedroom_7         -4463.4776    717.669     -6.219      0.000   -5870.721   -3056.235
# types_Duplex       -247.1567    215.498     -1.147      0.252    -669.717     175.404
# types_House         -40.5545     50.670     -0.800      0.424    -139.911      58.802
# types_Multifamily  -183.6261    250.676     -0.733      0.464    -675.164     307.912
# types_Townhouse    -382.3364     74.525     -5.130      0.000    -528.468    -236.204
# types_Triplex       318.8431    828.718      0.385      0.700   -1306.150    1943.836
# province_BC        1439.5657     61.726     23.322      0.000    1318.530    1560.601
# province_Manitoba    29.3508    104.611      0.281      0.779    -175.776     234.478
# province_Ontario    754.0994     45.720     16.494      0.000     664.450     843.749
# province_Quebec     873.7503     54.283     16.096      0.000     767.309     980.191
# province_SK        -143.0655     53.332     -2.683      0.007    -247.642     -38.489
# ==============================================================================
# Omnibus:                     2353.781   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           132739.771
# Skew:                           3.862   Prob(JB):                         0.00
# Kurtosis:                      36.509   Cond. No.                     7.60e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.6e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# R square in our model is 0.552 which means the model explain 55 percent of variation in rental price

# %%
err_series = model1.params - model1.conf_int()[0] ##calculating error bar length
coef_df = pd.DataFrame({'coef': model1.params.values[1:],
                        'err': err_series.values[1:],
                        'varname': err_series.index.values[1:]
                       })
fig, ax = plt.subplots(figsize=(8, 5))
coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', legend=False)
ax.set_ylabel('')
ax.set_xlabel('')
ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=10, 
           y=coef_df['coef'], color='black')
ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
# Out:
# <ipython-input-108-e0b1512c5b1c>:12: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   ax.scatter(x=pd.np.arange(coef_df.shape[0]),

# %% [markdown]
# The above graph shows the impact of different independent variables on rental price. as we can see, 1 bedroom, 2 bedrooms and 3 bedrooms places are more expensive that 0 bedroom places, holding other variables constant. Interestingly, 5 and 6 bedroom places are cheaper than 0 bedroom places, holding other variables constant. It is important to note that this is might be true because  5, 7 places are probably located in areas where the rentals are cheaper. Furthermore, rentals in BC, Ontario and Quebec are more expensive than the omitted category (Alberta). The coefficients of Saskatchewan and Manitoba are not significant (at 1 percent level). Therefore, there is no price in the rental price in these two provinces and Alberta. Regarding the rental type and price, it is clear that only townhouses are cheaper than appartments. Therefore, there is no difference between other types of places and the omitted category(price)

# %%
# evaluating the model by the test dataset
X_test=testing_data.drop(columns=['price'])
X_test= sm.add_constant(X_test) #adding constant to the model
Y_test=testing_data['price']
y_hat=model1.predict(X_test)
print('The mean square error for the test sample in the first model is %.2f' %mean_squared_error(Y_test, y_hat))
# Out:
# The mean square error for the test sample in the first model is 712048.18

# %% [markdown]
# # Model 2(ols) with city and without province

# %%
#creating training and testing datasets
df1=df.drop(columns=['Address','province','Latitude','Longitude'])# I only control for province. because adress and city are nested into province
df1['bedroom']=df1['bedroom'].astype("category") # I convert bedrooms to categorical because 
# it makes sense to think that there is not a linear relationship between 1 to 2 and 2 to 3 bedrooms places/
df1['size_sqf_q2']=df1['size_sqf']*df1['size_sqf'] 
#I added bigger places additional square feet has smaller impact on price than small places. 
df_dummies = pd.get_dummies(data=df1, drop_first=True)
training_data = df_dummies.sample(frac=0.8, random_state=25)
testing_data = df_dummies.drop(training_data.index)
training_data=training_data.reset_index(drop=True)
testing_data=testing_data.reset_index(drop=True)

# %%
X=training_data.drop(columns=['price'])
X= sm.add_constant(X) #adding constant to the model
Y=training_data['price']
model2 = sm.OLS(Y,X).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.617
# Method:                 Least Squares   F-statistic:                     106.6
# Date:                Thu, 10 Feb 2022   Prob (F-statistic):               0.00
# Time:                        14:56:04   Log-Likelihood:                -21678.
# No. Observations:                2694   AIC:                         4.344e+04
# Df Residuals:                    2652   BIC:                         4.369e+04
# Df Model:                          41
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  467.8596    160.861      2.908      0.004     152.434     783.286
# bathroom               448.4272     32.215     13.920      0.000     385.259     511.595
# size_sqf                -0.0146      0.178     -0.082      0.935      -0.363       0.334
# size_sqf_q2              0.0004   5.92e-05      7.217      0.000       0.000       0.001
# bedroom_1              213.8808     67.482      3.169      0.002      81.558     346.204
# bedroom_2              335.7791     79.703      4.213      0.000     179.492     492.066
# bedroom_3              401.0133    101.656      3.945      0.000     201.680     600.347
# bedroom_4              217.7116    134.974      1.613      0.107     -46.953     482.376
# bedroom_5            -1777.8162    310.928     -5.718      0.000   -2387.502   -1168.130
# bedroom_7            -4456.2621    665.908     -6.692      0.000   -5762.014   -3150.511
# types_Duplex           -52.5005    201.816     -0.260      0.795    -448.233     343.232
# types_House             24.1547     47.788      0.505      0.613     -69.550     117.859
# types_Multifamily     -236.8322    232.198     -1.020      0.308    -692.141     218.476
# types_Townhouse       -286.8667     69.692     -4.116      0.000    -423.523    -150.210
# types_Triplex           85.6075    765.937      0.112      0.911   -1416.288    1587.503
# city_Brampton         -377.6242    170.161     -2.219      0.027    -711.285     -43.963
# city_Burnaby          1028.5706    269.378      3.818      0.000     500.359    1556.783
# city_Calgary           -71.3777    144.611     -0.494      0.622    -354.939     212.183
# city_Edmonton         -374.9746    144.531     -2.594      0.010    -658.380     -91.570
# city_For_Mcmurray     -230.7216    268.047     -0.861      0.389    -756.323     294.880
# city_Grande_prairie   -502.8760    168.730     -2.980      0.003    -833.733    -172.019
# city_Hamilton          232.1293    170.329      1.363      0.173    -101.862     566.121
# city_Lethbridge       -352.5989    207.489     -1.699      0.089    -759.455      54.257
# city_London           -451.2217    224.815     -2.007      0.045    -892.051     -10.392
# city_Montreal          575.7577    143.372      4.016      0.000     294.625     856.890
# city_Moose_jaw        -456.9287    461.065     -0.991      0.322   -1361.011     447.154
# city_New_westminster   595.1684    367.961      1.617      0.106    -126.352    1316.689
# city_Oshawa           -626.8166    232.878     -2.692      0.007   -1083.457    -170.176
# city_Ottowa            463.6192    159.234      2.912      0.004     151.384     775.854
# city_Red_deer         -433.4371    207.897     -2.085      0.037    -841.094     -25.781
# city_Regina           -351.3245    149.237     -2.354      0.019    -643.958     -58.691
# city_Saskatoon        -391.9538    147.949     -2.649      0.008    -682.061    -101.846
# city_Surrey            145.3664    185.100      0.785      0.432    -217.589     508.322
# city_Swift_current    -425.8502    367.995     -1.157      0.247   -1147.437     295.737
# city_Toronto           854.7733    146.516      5.834      0.000     567.477    1142.070
# city_Vancouver        1746.8725    150.147     11.634      0.000    1452.455    2041.290
# city_chilliwack       -127.5002    288.784     -0.442      0.659    -693.765     438.765
# city_mississauga       646.3122    149.555      4.322      0.000     353.057     939.568
# city_selkirk          -645.9705    775.822     -0.833      0.405   -2167.247     875.306
# city_vaughan           313.9495    163.665      1.918      0.055      -6.974     634.873
# city_winnipeg         -222.8119    165.575     -1.346      0.179    -547.481     101.857
# city_yorkton          -509.5461    219.464     -2.322      0.020    -939.883     -79.209
# ==============================================================================
# Omnibus:                     2431.595   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           140217.844
# Skew:                           4.069   Prob(JB):                         0.00
# Kurtosis:                      37.394   Cond. No.                     8.18e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.18e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
err_series = model2.params - model1.conf_int()[0] ##calculating error bar length
coef_df = pd.DataFrame({'coef': model2.params.values[1:],
                        'err': err_series.values[1:],
                        'varname': err_series.index.values[1:]
                       })
fig, ax = plt.subplots(figsize=(8, 5))
coef_df.plot(x='varname', y='coef', kind='bar', 
             ax=ax, color='none', 
             yerr='err', legend=False)
ax.set_ylabel('')
ax.set_xlabel('')
ax.scatter(x=pd.np.arange(coef_df.shape[0]), 
           marker='s', s=10, 
           y=coef_df['coef'], color='red')
ax.axhline(y=0, linestyle='--', color='black', linewidth=4)
ax.xaxis.set_ticks_position('none')
# Out:
# <ipython-input-137-1bb92b231b11>:12: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   ax.scatter(x=pd.np.arange(coef_df.shape[0]),

# %% [markdown]
# The above graph shows the impact of different independent variables on the rental price. as we can see,  Vancouver is the most expensive city for rentals in Canada. On average, rentals located in Vancouver are $1746 more expensive than rentals in Abbotsford. Furthermore, rentals located in Toronto are cheaper than Vancouver but more expensive than Abbotsford

# %%
# evaluating the model by the test dataset
X_test=testing_data.drop(columns=['price'])
X_test= sm.add_constant(X_test) #adding constant to the model
Y_test=testing_data['price']
y_hat=model2.predict(X_test)
print('The mean square error for the test sample in the first model is %.2f' %mean_squared_error(Y_test, y_hat))
# Out:
# The mean square error for the test sample in the first model is 626249.70

# %% [markdown]
# The model 2 has smaller means square error
